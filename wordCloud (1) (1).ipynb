# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# %%
nltk.download("stopwords")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DS1\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DS1\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
file=open("agatha.txt","r").read()

# %%
stop_words=stopwords.words('english')

# %%
tokens=word_tokenize(file)

# %%
filtered_words=[]
for token in tokens:
    if token not in stop_words:
        filtered_words.append(token)
print(filtered_words)
# Out:
# ['Agatha', 'Christie', '-', 'Death', 'On', 'The', 'Nile', 'PART', 'ONE', 'CHAPTER', '1', 'Linnet', 'Ridgeway', '!', '``', 'That', "'s", 'Her', '.', "''", 'said', 'Mr.', 'Burnaby', ',', 'landlord', 'Three', 'Crowns', '.', 'He', 'nudged', 'companion', '.', 'The', 'two', 'men', 'stared', 'round', 'bucolic', 'eyes', 'slightly', 'open', 'mouths', '.', 'A', 'big', 'scarlet', 'Rolls-Royce', 'stopped', 'front', 'local', 'post', 'office', '.', 'A', 'girl', 'jumped', ',', 'girl', 'without', 'hat', 'wearing', 'frock', 'looked', '(', 'looked', ')', 'simple', '.', 'A', 'girl', 'golden', 'hair', 'straight', 'autocratic', 'features', '--', 'girl', 'lovely', 'shape', '--', 'girl', 'seldom', 'seen', 'MaltonunderWode', '.', 'With', 'quick', 'imperative', 'step', 'passed', 'post', 'office', '.', '``', 'That', "'s", '!', "'", '!', 'said', 'Mr.', 'Burnaby', '.', 'And', 'went', 'low', 'awed', 'voice', '.', '``', 'Millions', "'s", 'got', '....', 'Going', 'spend', 'thousands', 'place', '.', 'Swimming', 'poo
# ...

# %%
freq_words={}
for token in filtered_words:
    if token in freq_words:
        freq_words[token]=+1
    else:
        freq_words[token]=1
print(freq_words)
# Out:
# {'Agatha': 1, 'Christie': 1, '-': 1, 'Death': 1, 'On': 1, 'The': 1, 'Nile': 1, 'PART': 1, 'ONE': 1, 'CHAPTER': 1, '1': 1, 'Linnet': 1, 'Ridgeway': 1, '!': 1, '``': 1, 'That': 1, "'s": 1, 'Her': 1, '.': 1, "''": 1, 'said': 1, 'Mr.': 1, 'Burnaby': 1, ',': 1, 'landlord': 1, 'Three': 1, 'Crowns': 1, 'He': 1, 'nudged': 1, 'companion': 1, 'two': 1, 'men': 1, 'stared': 1, 'round': 1, 'bucolic': 1, 'eyes': 1, 'slightly': 1, 'open': 1, 'mouths': 1, 'A': 1, 'big': 1, 'scarlet': 1, 'Rolls-Royce': 1, 'stopped': 1, 'front': 1, 'local': 1, 'post': 1, 'office': 1, 'girl': 1, 'jumped': 1, 'without': 1, 'hat': 1, 'wearing': 1, 'frock': 1, 'looked': 1, '(': 1, ')': 1, 'simple': 1, 'golden': 1, 'hair': 1, 'straight': 1, 'autocratic': 1, 'features': 1, '--': 1, 'lovely': 1, 'shape': 1, 'seldom': 1, 'seen': 1, 'MaltonunderWode': 1, 'With': 1, 'quick': 1, 'imperative': 1, 'step': 1, 'passed': 1, "'": 1, 'And': 1, 'went': 1, 'low': 1, 'awed': 1, 'voice': 1, 'Millions': 1, 'got': 1, '....': 1, 'Going': 1, '
# ...

# %%
wordcloud=WordCloud(background_color="white").generate_from_frequencies(freq_words)

# %%
plt.figure(figsize=[15,15])
plt.imshow(wordcloud)

# %%
import numpy as np
from PIL import Image

# %%
mask = np.array(Image.open(r"C:\Users\DS1\Desktop\DataScience-11\35880twitter.png"))

# %%
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='white', collocations=False, stopwords = stop_words, mask=mask,contour_color='lightblue',contour_width=2).generate_from_frequencies(freq_words)

# %%
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.show()
